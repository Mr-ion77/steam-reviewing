# %% [markdown]
# # Estimación de Valoración y Recomendación de Juegos en Steam
#
# **Grupo 6**
# - **Rodrigo Juanes**
# - Noé López
# - Marc Velasco
# - Pablo Selma
# - Carlos Ribes
#
# ---
#
# ### Descripción del Proyecto
# Este proyecto tiene como objetivo:
# 1. **Obtener reseñas de Steam** mediante técnicas de web scrapping.
# 2. **Procesar las reseñas**  para el correcto entrenamiento de los siguientes modelos.
# 1. **Determinar si un usuario ha recomendado un juego** basándose en el análisis de su opinión.
# 2. **Sugerir juegos relacionados** a partir de un texto escrito, empleando las etiquetas de género y características de los juegos.
# 3. **Detectar ironía en las reseñas**, para mejorar la interpretación de las valoraciones.
#
# ---
#
# ### Tecnologías y Recursos
# - **WS/API:** SteamDB, AppReviews

# %% [markdown]
# ## Requirements
#
# Librerías necesarias para trabajar con el notebook.

# %%
# !pip install -r "requirements.txt"
# Out:
# Requirement already satisfied: spacy in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from -r requirements.txt (line 1)) (3.8.5)
# Requirement already satisfied: numpy in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from -r requirements.txt (line 2)) (2.2.5)
# Requirement already satisfied: requests in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from -r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: langdetect in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from -r requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: selenium in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from -r requirements.txt (line 5)) (4.32.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from -r requirements.txt (line 6)) (4.13.4)
# Collecting pyspellchecker (from -r requirements.txt (line 7))
#   Downloading pyspellchecker-0.8.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting stop_words (from -r requirements.txt (line 8))
#   Downloading stop-words-2018.7.23.tar.gz (31 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: unidecode in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from -r requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (3.0.8)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (2.11.4)
# Requirement already satisfied: jinja2 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from spacy->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from requests->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from requests->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from requests->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from requests->-r requirements.txt (line 3)) (2025.4.26)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: colorama in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy->-r requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy->-r requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: six in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from langdetect->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: trio~=0.17 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from selenium->-r requirements.txt (line 5)) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from selenium->-r requirements.txt (line 5)) (0.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from selenium->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 5)) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: outcome in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 5)) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: exceptiongroup in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from trio-websocket~=0.9->selenium->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium->-r requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from beautifulsoup4->-r requirements.txt (line 6)) (2.7)
# Requirement already satisfied: pycparser in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->-r requirements.txt (line 5)) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pablo\.conda\envs\entorno_scipy\lib\site-packages (from jinja2->spacy->-r requirements.txt (line 1)) (3.0.2)
# Downloading pyspellchecker-0.8.2-py3-none-any.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/7.1 MB 12.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.0/7.1 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 11.3 MB/s eta 0:00:00
# Building wheels for collected packages: stop_words
#   Building wheel for stop_words (setup.py): started
#   Building wheel for stop_words (setup.py): finished with status 'done'
#   Created wheel for stop_words: filename=stop_words-2018.7.23-py3-none-any.whl size=32917 sha256=ebefc8a986d3c32c5b9d0eb82e05405d0d68c7e16d30575bc4ea638eeeabe495
#   Stored in directory: c:\users\pablo\appdata\local\pip\cache\wheels\d0\1a\23\f12552a50cb09bcc1694a5ebb6c2cd5f2a0311de2b8c3d9a89
# Successfully built stop_words
# Installing collected packages: stop_words, pyspellchecker
#
#    -------------------- ------------------- 1/2 [pyspellchecker]
#    -------------------- ------------------- 1/2 [pyspellchecker]
#    ---------------------------------------- 2/2 [pyspellchecker]
#
# Successfully installed pyspellchecker-0.8.2 stop_words-2018.7.23
#   DEPRECATION: Building 'stop_words' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'stop_words'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %% [markdown]
# ## Carga de librerías y funciones

# %%
# Librerías necesarias
import spacy
import numpy as np
import requests
import pandas as pd
import re
import time

# Funiones necesarias
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from langdetect import detect

# %%
# !python -m spacy download es_core_news_md
# Out:
# Collecting es-core-news-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.8.0/es_core_news_md-3.8.0-py3-none-any.whl (42.3 MB)
#      ---------------------------------------- 0.0/42.3 MB ? eta -:--:--
#      - -------------------------------------- 2.1/42.3 MB 11.8 MB/s eta 0:00:04
#      ---- ----------------------------------- 4.7/42.3 MB 12.4 MB/s eta 0:00:04
#      ------ --------------------------------- 7.3/42.3 MB 12.6 MB/s eta 0:00:03
#      --------- ----------------------------- 10.2/42.3 MB 12.5 MB/s eta 0:00:03
#      ----------- --------------------------- 12.8/42.3 MB 12.4 MB/s eta 0:00:03
#      -------------- ------------------------ 15.5/42.3 MB 12.5 MB/s eta 0:00:03
#      ---------------- ---------------------- 18.4/42.3 MB 12.4 MB/s eta 0:00:02
#      ------------------- ------------------- 21.0/42.3 MB 12.6 MB/s eta 0:00:02
#      --------------------- ----------------- 23.1/42.3 MB 12.2 MB/s eta 0:00:02
#      ----------------------- --------------- 26.0/42.3 MB 12.3 MB/s eta 0:00:02
#      -------------------------- ------------ 28.6/42.3 MB 12.2 MB/s eta 0:00:02
#      ---------------------------- ---------- 31.2/42.3 MB 12.3 MB/s eta 0:00:01
#      ------------------------------ -------- 32.8/42.3 MB 12.3 MB/s eta 0:00:01
#      --------------------------------- ----- 36.7/42.3 MB 12.3 MB/s eta 0:00:01
#      ------------------------------------ -- 39.6/42.3 MB 12.4 MB/s eta 0:00:01
#      --------------------------------------  42.2/42.3 MB 12.4 MB/s eta 0:00:01
#      --------------------------------------- 42.3/42.3 MB 11.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')

# %% [markdown]
# # Web scrapping
#
# El objetivo es realizar el estudio sobre una gran variedad de reviews. La mejor manera de obtener esta gran cantidad de datos es mediante *web scrapping*. Dividiremos nuestro *web scrapping* en dos partes.
#
# * **Extracción de reseñas**
# * **Obtener una lista de juegos**

# %% [markdown]
# ## Extracción de reseñas.
#
# Empezaremos nuestro *web scrapping* estudiando como extraer reviews de un juego concreto. Como ejemplo, usaremos el videojuego Dota 2.
#
# El link asociado a las primeras $n$ reseñas del juego de steam con $id = \text{value}$ en lenguaje español es:
# - https://store.steampowered.com/appreviews/value?json=1&num_per_page=n&language=spanish
#
# A partir de esta API podemos obtener fácilmente las reseñas de cualquier juego.

# %%
# URL del endpoint de reseñas
url = 'https://store.steampowered.com/appreviews/570?json=1&num_per_page=100&language=spanish'

# Realiza la petición
response = requests.get(url)
data = response.json() 

# Itera por las reseñas
for review in data['reviews']:
    print("Usuario:", review['author']['steamid'])
    print("Comentario:", review['review'])
    print("¿Recomienda?", review['voted_up'])
    print('-' * 40)
# Out:
# Usuario: 76561198079669556
# Comentario: Para los que nunca lo han jugado y vinieron por recomendación o por el motivo que sea, no instalen esta m1erda de juego, por favor hagan caso a mi advertencia, tengo 10 años jugando esto, y dota ha arruinado mi vida, cuando creo que por fin dejé de jugarlo, algo o alguien o un pase de batalla, aparece de la nada y regresas por más, nunca es suficiente, nunca te llena, pierdes mas de lo que ganas y hay gente que merece algo peor que el infierno, este juego arruina la existencia misma, hay desesperación, agonía, desolación, peruanos, Techies, sufrimiento y un fuerte impulso por el su1c11dio, hermanos, por favor alejense de este juego y vivan sus vidas, enamorense, tengan hijos, viajen, coman, F0ll3n, vivan la vida, disfruten lo que nunca pude disfrutar, aun hay tiempo para ustedes, ya es tarde para mi.
# ¿Recomienda? False
# ----------------------------------------
# Usuario: 76561198288933432
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198198818855
# Comentario: De todos los Mobas, el más complejo, cuenta con un gran emparejamiento en cuanto a las habilidades de cada heroe
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198146489069
# Comentario: El juego está re bueno. Si te gusta la competencia, entonces este juego te atrapará. La complejidad de la mecánica es mas de la que aparenta a simple vista: muchos itmes para utilizar, muchos héroes con distintas habilidades para conocer, e infinitas combinaciones posibles para realizar y experimentar en la batalla. (Y)
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198079994950
# Comentario: por parte del jego esta bien, pero pedirle a los desarrolladores que solcionen prolemas de compatiilidad
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198287692510
# Comentario: No me deja entrar a las partidas me sale un error de red y no me selecciona region automatica. Lo que me pasa mas bien es de red porfavor solucionen eso para poder jugarlo
# ¿Recomienda? False
# ----------------------------------------
# Usuario: 76561198109266766
# Comentario: Hay tanto que se puede decir sobre este juego, bueno o malo, eso queda de lado, si quieres divertirte y renegar con tus amigos o desconocidos, debes jugarlo, para pasar el tiempo es muy entretenido!!!
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198118192355
# Comentario: Podría pasar horas jugando Dota 2 sin sentir "aburrimiento", me gusta la forma en la que se socializa con la comunidad y la variación de tácticas de juego ante diferentes heroes y objetos.
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198344591536
# Comentario: Si quieres quedarte sin hígado es el juego perfecto.
# Jugar MMR ya es demasiado irritante y muy disparejo.
# ¿Recomienda? False
# ----------------------------------------
# Usuario: 76561198211712512
# Comentario: El mejor juego de estrategia donde si cometes un pequeño error pierdes ok no xD lo recomiendo
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198161943412
# Comentario: Me encanta.
# Este juego en especial me gustó tanto que le tomé y dediqué un tiempo totalmente a este juego
# Y es por su jugabilidad y sus tantas formas de afrontar una partida
# Gracias Valve Corporación.
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198359654207
# Comentario: Me encanta este juego, se q si lo sigo jugando lograre algo posiblemente en un futuro adelante :V gracias volvo. Saludos
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198060525563
# Comentario: mejora de los modos de juego
# aumento de los objetos de coleccion
# aumentar las obciones de denuncia
# aumentoi de modos de juego
#
# ¿Recomienda? True
# ----------------------------------------
# Usuario: 76561198305410305
# Comentario: Dota 2 es un buen juego de estrategia , hay guerreros y distintas armas y poderes que hay que comprar con dinero de dota 2 , y otra cosa buena es que el juego es free to play , recomiendo este juego
# ¿Recomienda? True
# ----------------------------------------

# %% [markdown]
# De toda la información obtenida, tan solo nos interesa el texto de la reseña, y si el juego ha sido recomendado.

# %%
reviews = [review['review'] for review in data['reviews'] ]                # Obtener reviews a partir del diccionario
ratings  = [review['voted_up'] for review in data['reviews'] ]             # Obterner ratings asociados a las reviews anteriores

dataframe = pd.DataFrame({'reviews' : reviews , 'ratings' : ratings })     # Transformamos a formato pd.DataFrama para aprovechar sus múltiples utilidades
dataframe.head(10)
# Out:
#                                              reviews  ratings
# 0  Para los que nunca lo han jugado y vinieron po...    False
# 1  Un juego con excelsas mecanicas, pero con la c...    False
# 2  Es muy entretenido, si tienes horas libres pue...     True
# 3  La verdad esque es muy buen juego, lo actualiz...     True
# 4  después de 3 años siguiendo jugando, puedo dec...     True
# 5  Sinceramente esta bien es un buen juego, pero ...     True
# 6  Continuacion del Dota clasico del Warcraft 3 p...     True
# 7  Buen juego pero la comunidad es un desastre va...    False
# 8  bueno el dota 2 , es una moba que ace cambiar ...     True
# 9  oh..   solo hay que decir que una ves dentro j...     True

# %% [markdown]
# ## Obtener una lista de juegos
#
# Realizamos *Web Scraping* en la página de Steam, portal de venta de videojuegos, para obtener cuales son los juegos más jugados. De esta forma nos aseguramos que tenemos gran cantidad de comentarios en todos los juegos.
#
# Para realizar el *Web Scraping* utilizamos Selenium ya que necesitamos interactuar con la página de Steam. Concretamente necesitamos scrollear para alcanzar el final de las página y así que cargue más juegos.

# %%
# Necesitamos selenium para hacer scroll en la página y cargar elementos

n = 9 # Número de scrolls
      # La página empieza con 50 juegos y carga 50 más por scroll

# Configurar Chrome
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Inicializar driver
driver = webdriver.Chrome(options=chrome_options)

# Cargar la página
driver.get("https://store.steampowered.com/search/?untags=9130&filter=topsellers&ndl=1")

# Realizar scrolls
for _ in range(n):
    # Scroll hasta el final de la página
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Esperar a que cargue contenido nuevo
    time.sleep(2)

# Obtener el HTML después de todos los scrolls
html = driver.page_source

# Cerrar el navegador
driver.quit()

# %% [markdown]
# Una vez descargado el html, lo tratamos con *BeautifulSoup* y extraemos los nombre de los juegos así como sus ID.

# %%
soup = BeautifulSoup(html, "html.parser")

tabla = soup.find_all("div", id="search_resultsRows")[0]

# Generamos una lista de diccionarios con la id y el título del juego.

# NOTA: Algunos de los "juegos más vendidos" no son juegos, como Steam Deck.
# Se puede filtrar más adelante, ya que en
# https://store.steampowered.com/api/appdetails?appids=1675200
# aparece como "type": "hardware", en vez de "type": "game" o "type": "dlc".
juegos = []

for game in tabla.find_all("a"):
  juegos.append({'id': game['data-ds-appid'], 'title': game.find("span", class_="title").text})

# %% [markdown]
# Comprovemos que hemos conseguido una lista adecuada.

# %%
juegos[:20]
# Out:
# [{'id': '578080', 'title': 'PUBG: BATTLEGROUNDS'},
#  {'id': '730', 'title': 'Counter-Strike 2'},
#  {'id': '2349820', 'title': "Hero's Land"},
#  {'id': '3017860', 'title': 'DOOM: The Dark Ages'},
#  {'id': '1675200', 'title': 'Steam Deck'},
#  {'id': '1091500', 'title': 'Cyberpunk 2077'},
#  {'id': '553850', 'title': 'HELLDIVERS™ 2'},
#  {'id': '3164500', 'title': 'Schedule I'},
#  {'id': '490110', 'title': 'The Precinct'},
#  {'id': '3489700', 'title': 'Stellar Blade™'},
#  {'id': '292030', 'title': 'The Witcher 3: Wild Hunt'},
#  {'id': '1903340', 'title': 'Clair Obscur: Expedition 33'},
#  {'id': '2292800', 'title': 'Blacksmith Master'},
#  {'id': '2138330', 'title': 'Cyberpunk 2077: Phantom Liberty'},
#  {'id': '2669320', 'title': 'EA SPORTS FC™ 25'},
#  {'id': '252490', 'title': 'Rust'},
#  {'id': '3241660', 'title': 'R.E.P.O.'},
#  {'id': '1973530', 'title': 'Limbus Company'},
#  {'id': '381210', 'title': 'Dead by Daylight'},
#  {'id': '1086940', 'title': "Baldur's Gate 3"}]

# %% [markdown]
# ## Extracción de reseñas
#
# Una vez ya tenemos una lista de juegos con Ids, pasamos a la extracción de reseñas de cada juego.

# %%
all_reviews = []

for juego in juegos:
    game_id = juego['id']
    game_title = juego['title']
    url = f'https://store.steampowered.com/appreviews/{game_id}?json=1&num_per_page=100&language=spanish'
    try:
        response = requests.get(url)
        data = response.json()
        for review in data.get('reviews', []):
            all_reviews.append({
                'game_title': game_title,
                'game_id': game_id,
                'review': review['review'],
                'recommended': review['voted_up']
            })
    except Exception as e:
        print(f"Error loading reviews for {game_title} ({game_id}): {e}")

reviews_df = pd.DataFrame(all_reviews)

# %% [markdown]
# En el dataset obtenido tenemos:
# * **game_title**: Título del juego.
# * **game_id**: Identificador del juego.
# * **review**: La review.
# * **recommended**: Si se ha recomendado o no el juego.

# %%
reviews_df.head()
# Out:
#             game_title game_id  \
# 0  PUBG: BATTLEGROUNDS  578080
# 1  PUBG: BATTLEGROUNDS  578080
# 2  PUBG: BATTLEGROUNDS  578080
# 3  PUBG: BATTLEGROUNDS  578080
# 4  PUBG: BATTLEGROUNDS  578080
#
#                                               review  recommended
# 0  Más de 1000 horas y todavía no he ganado una s...         True
# 1  muy buen juego, hace falta optimización gráfic...         True
# 2  lo intente volver a jugar, no me deja entrar, ...        False
# 3  "El battle royale original que puso de moda mo...         True
# 4  PUBG fue uno de los primeros juegos tipo battl...         True

# %% [markdown]
# # Procesado del texto
#
# Si bien ya hemos obtenido una gran cantidad de reviews, cerrando el capítulo de *web scrapping*, ahora debemos preparar el texto para poder trabajar con este.

# %% [markdown]
# ## Detección de idioma
#
# Tan solo queremos trabajar con reviews en español, así que debemos detectar el idioma en el que está escrito cada review.
#
# A pesar de que disponemos de la función *detect* para detectar el idioma de cada review, primero tenemos que decidir qué hacer con todas las reviews sobre las cuales no podemos inferir un idioma.
#
# Primero, eliminaremos todas las reseñas que no contengan ni una sola letra.

# %%
# Elimina filas donde 'review' no contiene ninguna letra
reviews_df = reviews_df[reviews_df['review'].apply(lambda x: bool(re.search(r'[a-zA-ZáéíóúÁÉÍÓÚñÑ]', str(x))))].reset_index(drop=True)

# %% [markdown]
# A continuación, debemos identificar un notable tipo de review, el *ASCII art*.
#
# El *ASCII art* consiste en hacer dibujos usando distintos metacarácteres del alfabeto *ASCII*. El *ASCII art* está muy presente en estas reviews, pero no nos interesa trabajar con el, pues solo complicaría el entrenamiento de los modelos.
#
# Para identificar dichas reviews, intentaremos detectar el idioma con *detect*. Esta función no puede detectar el idoma de el texto formado mayoritariamente por metacarácteres, sirviendo como un gran detector de *ASCII art*.

# %%
languages = []

for review in reviews_df['review']:
    try:
        lang = detect(review)
    except Exception as e:
        lang = "art"
    languages.append(lang)

reviews_df['language'] = languages

# %% [markdown]
# Comprovemos si hemos logrado capturar el arte del que hablabamos.

# %%
art_reviews = reviews_df[reviews_df['language'] == 'art'].reset_index(drop=True)
print(art_reviews['review'].iloc[0])
# Out:
# Masterpiece
#
# Absolute cinema / cine absoluto
#
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀�
# ⠀⠀⠀⡟⠀⠀⠀⠉⢽⣶⣤⣤⡤⠼⠶⠲⠤⠤⣄⣽⠿⠁⠀⠀⠂⠀⠈⠻⣶⣷⣴⣶⠾⠿⡖⠶⠶⢤⣈⣿⣿⣦⣀⠀⢠⣎⣴⠏⠀⠀⠀
# ⠀⠀⡼⠁⠀⠀⣀⣶⠖⠋⠉⠀⠀⠀⠀⠀⠀⠰⣿⠉⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⡏⠁⠀⠀⠀⠀⠈⡉⠉⢻⣏⠙⠿⢿⣿⡿⠋⠀⠀⠀⠀
# ⠀⡼⠁⠀⢠⡶⠛⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠐⠀⠀⢽⡤⠀⠀⠀⠀⠀⠀⠀⠈⢸⣆⠀⠀⠙⣆⠀⠀⠀⠀⠀
# ⢸⣯⣠⣼⠿⠐⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⣷⣀⠀⠀⠀⠀⠀⠀⠀⠀⡆⢘⣇⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⢤⠀⠀⣸⣆⠀⠀⠀⠀
# ⢸⣿⠋⠀⠈⣧⣀⡀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⡧⠀⠀⠀⠀⠀⠀⠀⠀⠀⣽⣼⣴⣾⣿⢿⡆⠀⠀⠀
# ⠀⠻⡄⠸⠀⠈⠉⠉⣛⡿⠛⠻⠿⣶⣶⣶⣦⣤⡀⠘⢿⡄⠀⠀⠀⠀⠀⠀⠀⢠⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⠐⡾⣿⠿⣿⠃⣼⡇⠀⠀⠀
# ⠀⠀⢳⣀⣧⠀⠀⣠⡟⠀⠀⠀⠀⠀⠙⠻⣻⢿⣿⣤⡈⠁⠀⠀⠀⠀⠀⣠⣴⣿⣿⣏⠀⠀⠀⠀⠀⠀⠀⢀⣼⡟⠁⠀⢹⡾⠋⠀⠀⠀⠀
# ⠀⠀⠀⠙⠿⣷⣄⣿⠀⠀⠀⠀⠀⠀⠀⠀⠈⠑⢬⡻⢿⣷⣶⣶⣶⣾⣿⣿⠟⠻⣿⣿⣷⣶⣦⣤⣴⣶⣾⣿⠋⠀⢀⡴⠋⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠈⠻⠿⣒⣒⡀⠀⠀⠀⠀⠀⣰⣶⡆⠈⠓⠯⣍⢛⣛⢯⠉⠀⠀⠀⡼⠛⠛⣿⢿⣟⣻⢿⠋⢀⡤⠖⠁⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠉⠉⠉⠉⠙⡅⠀⠀⢀⡜⠋⠁⢸⠇⠀⠀⢸⡇⠀⠀⠈⢣⠀⠀⢺⠞⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣧⠀⢀⡎⠀⠀⢀⠞⠀⠀⠀⠀⢧⠀⠀⠀⠀⣇⠀⠀⢣⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⠃⠀⡜⠀⠀⢠⠋⠀⠀⠀⠀⠀⠀⠳⣄⠀⠀⠘⢆⠀⠀⠣⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡔⠋⠉⠁⢀⡜⠁⠀⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠘⡆⠀⠀⠈⠣⣄⡀⠉⠓⡄⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⠂⠀⠀⠐⠛⠒⠒⠒⠒⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⠒⠒⠒⠒⠒⠋⠛⠓⠚⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀

# %% [markdown]
# Ahora sí, podemos trabajar tan solo con las reseñas en castellano.

# %%
reseñas_df = reviews_df[reviews_df['language'] == 'es'].reset_index(drop=True)
reseñas_df.head(10)
# Out:
#             game_title game_id  \
# 0  PUBG: BATTLEGROUNDS  578080
# 1  PUBG: BATTLEGROUNDS  578080
# 2  PUBG: BATTLEGROUNDS  578080
# 3  PUBG: BATTLEGROUNDS  578080
# 4  PUBG: BATTLEGROUNDS  578080
# 5  PUBG: BATTLEGROUNDS  578080
# 6  PUBG: BATTLEGROUNDS  578080
# 7  PUBG: BATTLEGROUNDS  578080
# 8  PUBG: BATTLEGROUNDS  578080
# 9  PUBG: BATTLEGROUNDS  578080
#
#                                               review  recommended language
# 0  Más de 1000 horas y todavía no he ganado una s...         True       es
# 1  muy buen juego, hace falta optimización gráfic...         True       es
# 2  lo intente volver a jugar, no me deja entrar, ...        False       es
# 3  "El battle royale original que puso de moda mo...         True       es
# 4  PUBG fue uno de los primeros juegos tipo battl...         True       es
# 5  Ta bueno, perfecto para desequilibrarte mental...         True       es
# 6  La fisica aplicada a los movimientos, los conc...         True       es
# 7  es la mea tula de juego, jueguen nomas cabros ...         True       es
# 8  injugable. mecanicas de disparo imposibles si ...        False       es
# 9  juego de batalla muy realista y bastante emoci...         True       es

# %% [markdown]
# ## Limpieza y normalización del texto

# %% [markdown]
# El siguiente paso, muy necesario en nuestro contexto, es la corrección ortográfica: las reseñas de Steam muchas veces contienen _slangs_, insultos y un tono informal, lo cual dificulta cualquier tipo de clasificación. En este caso, haremos uso de la librería **spellchecker**:

# %%
import re, string
from unidecode import unidecode
from stop_words import get_stop_words

nlp=spacy.load('es_core_news_md')
stop_words = get_stop_words('spanish')

pattern2 = re.compile('[{}]'.format(re.escape(string.punctuation))) #selecciona símbolos de puntuación

def clean_text(text):
    """Limpiamos las menciones y URL del texto. Luego convertimos en tokens
    eliminamos los tokens que son signos de puntuación, convertimos en
    minúsculas y quitamos signos de puntuación. Para terminar
    volvemos a convertir en cadena de texto"""
    text = re.sub(r'@[\w_]+|https?://[\w_./]+', '', text) #elimina menciones y URL
    tokens = nlp(text)
    tokens = [tok.lower_ for tok in tokens if not tok.is_punct and not tok.is_space]
    filtered_tokens = [pattern2.sub('', token) for token in tokens if not (token in stop_words)] #obvia stop_words y después quita signos de puntuación
    filtered_text = ' '.join(filtered_tokens)

    return filtered_text

def lemmatize_text(text):
    """Convertimos el texto a tokens, extraemos el lema de cada token
    y volvemos a convertir en cadena de texto sin acentos"""
    tokens = nlp(text)
    lemmatized_tokens = [tok.lemma_ for tok in tokens]
    lemmatized_text = ' '.join(lemmatized_tokens)
    deaccented_str = unidecode(lemmatized_text)

    return deaccented_str

# %%
# Añade columna con el texto limpio
reseñas_df['clean_text'] = reseñas_df['review'].apply(clean_text)

# Añade columna con la lematización del texto limpio
reseñas_df['lemmatized_text'] = reseñas_df['clean_text'].apply(lemmatize_text)

# %%
# Reordena las columnas para que 'clean_text' y 'lemmatized_text' estén después de 'review'
columnas = list(reseñas_df.columns)
columnas.remove('language')

# Reordena las columnas
nueva_orden = columnas.copy()
if 'review' in columnas and 'clean_text' in columnas and 'lemmatized_text' in columnas:
    idx = columnas.index('review')
    # Quita las columnas para reinsertarlas en orden correcto
    nueva_orden.remove('clean_text')
    nueva_orden.remove('lemmatized_text')
    nueva_orden = (
        nueva_orden[:idx+1] +
        ['clean_text', 'lemmatized_text'] +
        nueva_orden[idx+1:]
    )

reseñas_df = reseñas_df[nueva_orden]

# %%
reseñas_df.head(10)
# Out:
#             game_title game_id  \
# 0  PUBG: BATTLEGROUNDS  578080
# 1  PUBG: BATTLEGROUNDS  578080
# 2  PUBG: BATTLEGROUNDS  578080
# 3  PUBG: BATTLEGROUNDS  578080
# 4  PUBG: BATTLEGROUNDS  578080
# 5  PUBG: BATTLEGROUNDS  578080
# 6  PUBG: BATTLEGROUNDS  578080
# 7  PUBG: BATTLEGROUNDS  578080
# 8  PUBG: BATTLEGROUNDS  578080
# 9  PUBG: BATTLEGROUNDS  578080
#
#                                               review  \
# 0  Más de 1000 horas y todavía no he ganado una s...
# 1  muy buen juego, hace falta optimización gráfic...
# 2  lo intente volver a jugar, no me deja entrar, ...
# 3  "El battle royale original que puso de moda mo...
# 4  PUBG fue uno de los primeros juegos tipo battl...
# 5  Ta bueno, perfecto para desequilibrarte mental...
# 6  La fisica aplicada a los movimientos, los conc...
# 7  es la mea tula de juego, jueguen nomas cabros ...
# 8  injugable. mecanicas de disparo imposibles si ...
# 9  juego de batalla muy realista y bastante emoci...
#
#                                           clean_text  \
# 0  más 1000 horas y todavía no he ganado sola vez...
# 1  muy buen juego hace falta optimización gráfica...
# 2  intente volver jugar no deja entrar tiene prob...
# 3  battle royale original que puso moda morir sin...
# 4  pubg fue uno primeros juegos tipo battle royal...
# 5  ta bueno perfecto para desequilibrarte mentalm...
# 6  fisica aplicada movimientos conceptos sencillo...
# 7  es mea tula juego jueguen nomas cabros es como...
# 8  injugable mecanicas disparo imposibles si no e...
# 9  juego batalla muy realista y bastante emociona...
#
#                                      lemmatized_text  recommended
# 0  más 1000 hora y todavía no haber ganar solo ve...         True
# 1  mucho buen juego hacer falta optimización gráf...         True
# 2  intentar volver jugar no dejar entrar tener pr...        False
# 3  battle royale original que poner moda morir si...         True
# 4  pubg ser uno primero juegos tipo battle royale...         True
# 5  to bueno perfecto para desequilibrarte mentalm...         True
# 6  fisico aplicado movimiento concepto sencillo q...         True
# 7  ser mea tula juego jugar noma cabro ser como p...         True
# 8  injugable mecanica disparo imposible si no ser...        False
# 9  juego batalla mucho realista y bastante emocio...         True

# %% [markdown]
# ## Exportación del dataset
#
# Una vez preparado el datset, lo guardamos en formato .csv para el uso con modelos.

# %%
reseñas_df.to_csv('steam_reseñas.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Extracción de la información de los juegos
#
# Obtenemos mediante web scraping información en español de los juegos de los cuales hemos sacado los comentarios: un resumen del juego, los géneros y las categorias del juego.

# %%
ids = [game['id'] for game in juegos]
game_description_list = []
genres_list = []
categories_list = []

for id in ids:
  url = 'https://store.steampowered.com/api/appdetails?appids=' + id + '&l=spanish'

  # Realiza la petición
  response_2 = requests.get(url)
  data_2 = response_2.json()

  game_description_list.append(re.sub(r'<.+?>', ' ', data_2[id]['data']['detailed_description']))

  genres = []
  if 'genres' in data_2[id]['data'].keys():
    for genre in data_2[id]['data']['genres']:
      genres.append(genre['description'])
  genres_list.append(genres)

  categories = []
  if 'categories' in data_2[id]['data'].keys():
    for category in data_2[id]['data']['categories']:
      categories.append(category['description'])
  categories_list.append(categories)

  time.sleep(2)

# %% [markdown]
# Guardando en un dataset la información:
# * **ids**: Identificador del juego.
# * **game_description**: Resumen del juego.
# * **genres**: Géneros del juego.
# * **categories**: Categorías del juego.

# %%
game_description_df = pd.DataFrame({'game_id' : ids, 
                            'game_description' : game_description_list, 
                            'genres' : genres_list, 
                            'categories' : categories_list})
game_description_df.head(10)
# Out:
#    game_id                                   game_description  \
# 0   578080          ATERRIZA,       Aterriza en una selecc...
# 1      730  Durante las dos últimas décadas, Counter‑Strik...
# 2  3017860   PREMIUM EDITION    Resiste las acometidas y l...
# 3  1091500   Cyberpunk 2077: Ultimate Edition      Descubr...
# 4   553850   Digital Deluxe Edition     La edición incluye...
# 5  3164500   Schedule I drugs, substances, or chemicals ar...
# 6   490110   Discord      Acerca del juego  Eres el agente...
# 7   292030   DESCUBRE LA HISTORIA PREVIA A THE WITCHER IV ...
# 8  1903340   Digital Deluxe Edition    La edición Deluxe i...
# 9  2292800   En Blacksmith Master diriges una herrería med...
#
#                                               genres  \
# 0  [Acción, Aventura, Multijugador masivo, Free t...
# 1                             [Acción, Free to Play]
# 2                                           [Acción]
# 3                                              [Rol]
# 4                                           [Acción]
# 5  [Acción, Indie, Simuladores, Estrategia, Acces...
# 6                       [Acción, Indie, Simuladores]
# 7                                              [Rol]
# 8                                      [Acción, Rol]
# 9       [Simuladores, Estrategia, Acceso anticipado]
#
#                                           categories
# 0  [Multijugador, JcJ, JcJ en línea, Estadísticas...
# 1  [Multijugador, Multijugador multiplataforma, C...
# 2  [Un jugador, Logros de Steam, Compat. total co...
# 3  [Un jugador, Logros de Steam, Compat. total co...
# 4  [Multijugador, Cooperativo, Cooperativo en lín...
# 5  [Un jugador, Multijugador, Cooperativo, Cooper...
# 6  [Un jugador, Logros de Steam, Compat. total co...
# 7  [Un jugador, Logros de Steam, Cromos de Steam,...
# 8  [Un jugador, Logros de Steam, Compat. total co...
# 9  [Un jugador, Logros de Steam, Cromos de Steam,...

# %% [markdown]
# ## Exportación del dataset
#
# Al igual que con las reseñas, guardamos el dataset en formato .csv para el uso con modelos.

# %%
game_description_df.to_csv('steam_descripciones_juegos.csv', index=False, encoding='utf-8')
